# %% [markdown]
# <a href="https://colab.research.google.com/github/lidimoura/challenge1-data-science-Alura-Store/blob/main/AluraStoreBrasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# 1    cartao_credito                       4 -22.25 -42.66
# 2    cartao_credito                       1 -15.83 -47.86
# 3            boleto                       1 -30.17 -53.50
# 4            boleto                       1 -18.10 -44.38

# %% [markdown]
# ### Breve análise de cada dataframe com head()

# %%
# Breve análise de cada data frame com head()
loja2.head()
# Out:
#                  Produto   Categoria do Produto    Preço      Frete  \
# 0  Cadeira de escritório                 moveis   378.20  20.421138
# 1               Pandeiro  instrumentos musicais   102.37   3.035334
# 2              Cama king                 moveis   591.13  31.759020
# 3              Cama king                 moveis  1208.24  61.919584
# 4  Cadeira de escritório                 moveis   530.41  25.827176
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     04/08/2021    Thiago Silva              MG                    1
# 1     26/11/2020   Bianca Santos              RJ                    3
# 2     22/10/2021    Thiago Silva              SC                    5
# 3     04/05/2022   Larissa Alves              RS                    5
# 4     26/02/2022  Lucas Oliveira              SP                    4
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0            boleto                       1 -18.10 -44.38
# 1    cartao_credito                       4 -22.25 -42.66
# 2    cartao_credito                      10 -27.45 -50.95
# 3    cartao_credito                      10 -30.17 -53.50
# 4    cartao_credito                       3 -22.19 -48.79

# %%
loja3.head()
# Out:
#               Produto   Categoria do Produto    Preço      Frete  \
# 0  Secadora de roupas       eletrodomesticos  1713.50  88.823159
# 1              Cômoda                 moveis   386.81  18.180908
# 2              Violão  instrumentos musicais   404.62  23.197592
# 3       Bola de vôlei        esporte e lazer    78.40   4.463341
# 4       Guarda roupas                 moveis   694.76  34.578319
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     17/12/2021  Camila Ribeiro              CE                    4
# 1     10/02/2021   Larissa Alves              RS                    3
# 2     22/01/2023  Lucas Oliveira              SP                    5
# 3     22/03/2022     Pedro Gomes              BA                    4
# 4     12/01/2022   Bianca Santos              SP                    1
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       4  -5.20 -39.53
# 1    cartao_credito                       1 -30.17 -53.50
# 2    cartao_credito                       3 -22.19 -48.79
# 3    cartao_credito                       6 -13.29 -41.71
# 4    cartao_credito                       1 -22.19 -48.79

# %%
loja4.head()
# Out:
#                Produto Categoria do Produto    Preço      Frete  \
# 0          Lava louças     eletrodomesticos  1446.46  74.604083
# 1             Cama box               moveis   631.70  33.919251
# 2     Bola de basquete      esporte e lazer    31.54   0.000000
# 3  Modelagem preditiva               livros    76.93   1.680730
# 4       Fone de ouvido          eletronicos   185.14   7.442587
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     11/11/2022    Rafael Costa              SP                    4
# 1     03/01/2020    Thiago Silva              GO                    5
# 2     25/12/2022   Larissa Alves              MG                    5
# 3     23/11/2021  Lucas Oliveira              MG                    3
# 4     25/04/2022   Bianca Santos              SP                    4
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       3 -22.19 -48.79
# 1    cartao_credito                       2 -15.98 -49.86
# 2            boleto                       1 -18.10 -44.38
# 3            boleto                       1 -18.10 -44.38
# 4    cartao_credito                       7 -22.19 -48.79

# %% [markdown]
# ### Breve análise de cada datraframe com info()

# %%
loja.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Produto                 2359 non-null   object
#  1   Categoria do Produto    2359 non-null   object
#  2   Preço                   2359 non-null   float64
#  3   Frete                   2359 non-null   float64
#  4   Data da Compra          2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Local da compra         2359 non-null   object
#  7   Avaliação da compra     2359 non-null   int64
#  8   Tipo de pagamento       2359 non-null   object
#  9   Quantidade de parcelas  2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
loja2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Produto                 2359 non-null   object
#  1   Categoria do Produto    2359 non-null   object
#  2   Preço                   2359 non-null   float64
#  3   Frete                   2359 non-null   float64
#  4   Data da Compra          2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Local da compra         2359 non-null   object
#  7   Avaliação da compra     2359 non-null   int64
#  8   Tipo de pagamento       2359 non-null   object
#  9   Quantidade de parcelas  2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
loja3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Produto                 2359 non-null   object
#  1   Categoria do Produto    2359 non-null   object
#  2   Preço                   2359 non-null   float64
#  3   Frete                   2359 non-null   float64
#  4   Data da Compra          2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Local da compra         2359 non-null   object
#  7   Avaliação da compra     2359 non-null   int64
#  8   Tipo de pagamento       2359 non-null   object
#  9   Quantidade de parcelas  2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
loja4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2358 entries, 0 to 2357
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Produto                 2358 non-null   object
#  1   Categoria do Produto    2358 non-null   object
#  2   Preço                   2358 non-null   float64
#  3   Frete                   2358 non-null   float64
#  4   Data da Compra          2358 non-null   object
#  5   Vendedor                2358 non-null   object
#  6   Local da compra         2358 non-null   object
#  7   Avaliação da compra     2358 non-null   int64
#  8   Tipo de pagamento       2358 non-null   object
#  9   Quantidade de parcelas  2358 non-null   int64
#  10  lat                     2358 non-null   float64
#  11  lon                     2358 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.2+ KB

# %% [markdown]
# ## Unificação de todas as lojas num só dataframe e tratamento de dados
# Unificando todas as lojas num único dataframe já que tem a mesma estrutura e realizando pequenos ajustes técnicos para facilitar a análise.

# %%
# Adicionando uma coluna 'Loja' em cada dataframe para identificar a origem dos dados após a unificação
loja['Loja'] = 'Loja 1'
loja2['Loja'] = 'Loja 2'
loja3['Loja'] = 'Loja 3'
loja4['Loja'] = 'Loja 4'

# Unificação dos dados concatenando os 4 dataframes em um único chamado 'df' e usando o parâmetro ignore_index=True para evitar indíces duplicados
df = pd.concat([loja, loja2, loja3, loja4], ignore_index=True)

# Verificação exibindo 5 amostras aleatórias para garantir que as lojas foram misturadas corretamente
display(df.sample(5))
# Out:
#                  Produto   Categoria do Produto    Preço      Frete  \
# 9079  Lavadora de roupas       eletrodomesticos  1602.78  85.626339
# 3938         Micro-ondas       eletrodomesticos   564.46  30.586901
# 7974         Lava louças       eletrodomesticos  1322.50  70.702272
# 8760    Blocos de montar             brinquedos    53.96   0.000000
# 2657            Guitarra  instrumentos musicais   927.30  49.659061
#
#      Data da Compra          Vendedor Local da compra  Avaliação da compra  \
# 9079     30/07/2022     Bianca Santos              RJ                    5
# 3938     02/04/2022       Pedro Gomes              SP                    5
# 7974     10/01/2023  Mariana Ferreira              SP                    1
# 8760     08/03/2021       Pedro Gomes              SP                    1
# 2657     21/03/2023  Isabella Pereira              SP                    1
#
#      Tipo de pagamento  Quantidade de parcelas    lat    lon    Loja
# 9079    cartao_credito                       3 -22.25 -42.66  Loja 4
# 3938    cartao_credito                       1 -22.19 -48.79  Loja 2
# 7974    cartao_credito                       8 -22.19 -48.79  Loja 4
# 8760            boleto                       1 -22.19 -48.79  Loja 4
# 2657             cupom                       1 -22.19 -48.79  Loja 2

# %%
# Diagnóstico de qualidade para garantir que não há nenhum item nulo
print(' Quandidade de nulos ')
display(df.isnull().sum())

# Verificando se há itens duplicados
duplicados = df.duplicated().sum()
print(f'Linhas duplicads encontradas: {duplicados}')
# Out:
#  Quandidade de nulos
# Produto                   0
# Categoria do Produto      0
# Preço                     0
# Frete                     0
# Data da Compra            0
# Vendedor                  0
# Local da compra           0
# Avaliação da compra       0
# Tipo de pagamento         0
# Quantidade de parcelas    0
# lat                       0
# lon                       0
# Loja                      0
# dtype: int64
# Linhas duplicads encontradas: 0

# %%
# Ajustando datas para que o pandas entenda que a coluna 'Data da Compra' é tempo, não texto e usando o dayfirst=True pra garantir o formato brasileiro que é Dia/Mês/Ano
df['Data da Compra'] = pd.to_datetime(df['Data da Compra'], dayfirst=True)

# Criando colunas temporais (para análises futuras) Isso permitirá avaliar melhor o faturamento em cada período
df['Ano'] = df['Data da Compra'].dt.year
df['Mes'] =  df['Data da Compra'].dt.month

# Arredondado valores financeiros
df[['Preço', 'Frete']] = df[['Preço', 'Frete']].round(2)

# Verificação final
display(df.sample(5))
# Out:
#             Produto   Categoria do Produto    Preço   Frete Data da Compra  \
# 1858       Smart TV            eletronicos  1978.20  105.86     2020-01-27
# 6734     Smartwatch            eletronicos   166.04   18.70     2022-03-22
# 7348       Guitarra  instrumentos musicais   946.34   47.97     2021-08-01
# 6208      Cama king                 moveis   992.17   53.11     2022-12-03
# 4058  Bola de vôlei        esporte e lazer    64.86    3.98     2020-09-06
#
#            Vendedor Local da compra  Avaliação da compra Tipo de pagamento  \
# 1858   Thiago Silva              TO                    4    cartao_credito
# 6734    Pedro Gomes              BA                    4            boleto
# 7348  Felipe Santos              SP                    2    cartao_credito
# 6208   Thiago Silva              MG                    5    cartao_credito
# 4058   Thiago Silva              PE                    1             cupom
#
#       Quantidade de parcelas    lat    lon    Loja   Ano  Mes
# 1858                      10  -9.46 -48.26  Loja 1  2020    1
# 6734                       1 -13.29 -41.71  Loja 3  2022    3
# 7348                       3 -22.19 -48.79  Loja 4  2021    8
# 6208                       1 -18.10 -44.38  Loja 3  2022   12
# 4058                       1  -8.38 -37.86  Loja 2  2020    9

# %%
## Importando as outras bibliotecas que serão usadas
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Análise do faturamento

# %%
# Agrupando pelo identificador da Loja e somando o faturamento
faturamento_por_loja = df.groupby('Loja')['Preço'].sum().reset_index(name='faturamento_total').sort_values('faturamento_total', ascending=False)

# Exibindo o faturamento total
display(faturamento_por_loja.style.format({'faturamento_total': '{:,.2f}'}, thousands='.', decimal=','))
# Out:
# <style type="text/css">
# </style>
# <table id="T_3399f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3399f_level0_col0" class="col_heading level0 col0" >Loja</th>
#       <th id="T_3399f_level0_col1" class="col_heading level0 col1" >faturamento_total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3399f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3399f_row0_col0" class="data row0 col0" >Loja 1</td>
#       <td id="T_3399f_row0_col1" class="data row0 col1" >1.534.509,12</td>
#     </tr>
#     <tr>
#       <th id="T_3399f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3399f_row1_col0" class="data row1 col0" >Loja 2</td>
#       <td id="T_3399f_row1_col1" class="data row1 col1" >1.488.459,06</td>
#     </tr>
#     <tr>
#       <th id="T_3399f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3399f_row2_col0" class="data row2 col0" >Loja 3</td>
#       <td id="T_3399f_row2_col1" class="data row2 col1" >1.464.025,03</td>
#     </tr>
#     <tr>
#       <th id="T_3399f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3399f_row3_col0" class="data row3 col0" >Loja 4</td>
#       <td id="T_3399f_row3_col1" class="data row3 col1" >1.384.497,58</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Criando gráfico visual com seaborn
plt.figure(figsize=(10,6))
grafico_fat = sns.barplot(x='Loja', y='faturamento_total', hue='Loja', data=faturamento_por_loja, palette='viridis', legend=False)
plt.title('Ranking de faturamento por loja (R$)', fontsize=16, fontweight='bold')
plt.ylabel('Faturamento (R$)', fontsize=14)
plt.xlabel('Loja', fontsize=14)

# Adicionando rótulos de dados nas barras
for i in grafico_fat.containers:
    grafico_fat.bar_label(i, fmt=lambda v: f'R$ {v/1_000_000:.2f}M',fontsize=12, color='black', padding=3)

# Usando a função tight_layout para ajustar o layout do gráfico
plt.tight_layout()

# Salvando o graáfico para o reademe
plt.savefig('grafico_faturamento.png')
plt.show()

# %% [markdown]
# # 2. Vendas por categoria

# %%
# Contagem de vendas por categorias em cada loja usando unstack() para transformar as categorias em colunas pra faciliatar a leitura visual
vendas_categoria = df.groupby(['Loja', 'Categoria do Produto']).size().unstack().fillna(0)

# Visualizando a tabela com destaque para as categorias mais populares de cada loja com fundo laranja
display(vendas_categoria.style.format({col: '{:,.0f}' for col in vendas_categoria.columns}).highlight_max(color='orange', axis=1))
# Out:
# <style type="text/css">
# #T_5715d_row0_col6, #T_5715d_row1_col6, #T_5715d_row2_col6, #T_5715d_row3_col6 {
#   background-color: orange;
# }
# </style>
# <table id="T_5715d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Categoria do Produto</th>
#       <th id="T_5715d_level0_col0" class="col_heading level0 col0" >brinquedos</th>
#       <th id="T_5715d_level0_col1" class="col_heading level0 col1" >eletrodomesticos</th>
#       <th id="T_5715d_level0_col2" class="col_heading level0 col2" >eletronicos</th>
#       <th id="T_5715d_level0_col3" class="col_heading level0 col3" >esporte e lazer</th>
#       <th id="T_5715d_level0_col4" class="col_heading level0 col4" >instrumentos musicais</th>
#       <th id="T_5715d_level0_col5" class="col_heading level0 col5" >livros</th>
#       <th id="T_5715d_level0_col6" class="col_heading level0 col6" >moveis</th>
#       <th id="T_5715d_level0_col7" class="col_heading level0 col7" >utilidades domesticas</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Loja</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5715d_level0_row0" class="row_heading level0 row0" >Loja 1</th>
#       <td id="T_5715d_row0_col0" class="data row0 col0" >324</td>
#       <td id="T_5715d_row0_col1" class="data row0 col1" >312</td>
#       <td id="T_5715d_row0_col2" class="data row0 col2" >448</td>
#       <td id="T_5715d_row0_col3" class="data row0 col3" >284</td>
#       <td id="T_5715d_row0_col4" class="data row0 col4" >182</td>
#       <td id="T_5715d_row0_col5" class="data row0 col5" >173</td>
#       <td id="T_5715d_row0_col6" class="data row0 col6" >465</td>
#       <td id="T_5715d_row0_col7" class="data row0 col7" >171</td>
#     </tr>
#     <tr>
#       <th id="T_5715d_level0_row1" class="row_heading level0 row1" >Loja 2</th>
#       <td id="T_5715d_row1_col0" class="data row1 col0" >313</td>
#       <td id="T_5715d_row1_col1" class="data row1 col1" >305</td>
#       <td id="T_5715d_row1_col2" class="data row1 col2" >422</td>
#       <td id="T_5715d_row1_col3" class="data row1 col3" >275</td>
#       <td id="T_5715d_row1_col4" class="data row1 col4" >224</td>
#       <td id="T_5715d_row1_col5" class="data row1 col5" >197</td>
#       <td id="T_5715d_row1_col6" class="data row1 col6" >442</td>
#       <td id="T_5715d_row1_col7" class="data row1 col7" >181</td>
#     </tr>
#     <tr>
#       <th id="T_5715d_level0_row2" class="row_heading level0 row2" >Loja 3</th>
#       <td id="T_5715d_row2_col0" class="data row2 col0" >315</td>
#       <td id="T_5715d_row2_col1" class="data row2 col1" >278</td>
#       <td id="T_5715d_row2_col2" class="data row2 col2" >451</td>
#       <td id="T_5715d_row2_col3" class="data row2 col3" >277</td>
#       <td id="T_5715d_row2_col4" class="data row2 col4" >177</td>
#       <td id="T_5715d_row2_col5" class="data row2 col5" >185</td>
#       <td id="T_5715d_row2_col6" class="data row2 col6" >499</td>
#       <td id="T_5715d_row2_col7" class="data row2 col7" >177</td>
#     </tr>
#     <tr>
#       <th id="T_5715d_level0_row3" class="row_heading level0 row3" >Loja 4</th>
#       <td id="T_5715d_row3_col0" class="data row3 col0" >338</td>
#       <td id="T_5715d_row3_col1" class="data row3 col1" >254</td>
#       <td id="T_5715d_row3_col2" class="data row3 col2" >451</td>
#       <td id="T_5715d_row3_col3" class="data row3 col3" >277</td>
#       <td id="T_5715d_row3_col4" class="data row3 col4" >170</td>
#       <td id="T_5715d_row3_col5" class="data row3 col5" >187</td>
#       <td id="T_5715d_row3_col6" class="data row3 col6" >480</td>
#       <td id="T_5715d_row3_col7" class="data row3 col7" >201</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Criando o gráfico de barras empilhadas para analisar melhor as vendas das categorias de cada loja
ax = vendas_categoria.plot(kind='bar', stacked=True, figsize=(12,7), colormap='tab10')
plt.title('Vendas por categoria de produto', fontsize=16, fontweight='bold')
plt.ylabel('Quantidade de vendas', fontsize=14)

# Obtendo os handles do gráfico
handles, _ = ax.get_legend_handles_labels()

# Usando as colunas do DataFrame como rótulos da legenda para garantir a ordem (invertendo ambas handles e labels para corresponder à ordem de empilhamento)
plt.legend(handles[::-1], vendas_categoria.columns[::-1], title='Categorias', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

# Salvando gráfico
plt.savefig('grafico_vendas_categorias.png')
plt.show()

# %%
# Faturamento total de cada categoria

# %%
# Porcentagem de faturamento total de cada categorai para analisar as que  mais se destacam

# %% [markdown]
# # 3. Média de avaliação das lojas

# %%
# Calculando a média das estrelas de avaliações de cada loja
avaliacao_media = df.groupby('Loja')['Avaliação da compra'].mean().reset_index(name='media_avaliacao').sort_values('media_avaliacao', ascending=False).round(2)

# Visualizando a média das avaliações de cada loja
display(avaliacao_media)
# Out:
#      Loja  media_avaliacao
# 2  Loja 3             4.05
# 1  Loja 2             4.04
# 3  Loja 4             4.00
# 0  Loja 1             3.98

# %%
# Agrupando por categoria para calcular a avaliação média
avaliacao_por_categoria = df.groupby('Categoria do Produto')['Avaliação da compra'].mean().reset_index().sort_values('Avaliação da compra', ascending=False).round(2)

# Exibindo a média das avaliações por categoria
display(avaliacao_por_categoria)
# Out:
#     Categoria do Produto  Avaliação da compra
# 0             brinquedos                 4.07
# 6                 moveis                 4.03
# 1       eletrodomesticos                 4.01
# 5                 livros                 4.00
# 4  instrumentos musicais                 4.00
# 2            eletronicos                 3.99
# 3        esporte e lazer                 3.99
# 7  utilidades domesticas                 3.98

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
# Descobrindo os produtos mais e menos vendidos de cada loja - verificando os 5 mais vendidos e os 5 menos vendidos
produtos_mais_vendidos = df.groupby(['Loja', 'Produto']).size().reset_index(name='quantidade_vendida').sort_values('quantidade_vendida', ascending=False).head(5)
produtos_menos_vendidos = df.groupby(['Loja', 'Produto']).size().reset_index(name='quantidade_vendida').sort_values('quantidade_vendida', ascending=True).head(5)

# Exibindo o resultado com os 5 mais vendidos e os 5 menos vendidos de cada loja
display(produtos_mais_vendidos)
print('----------')
display(produtos_menos_vendidos)
# Out:
#        Loja                   Produto  quantidade_vendida
# 79   Loja 2  Iniciando em programação                  65
# 88   Loja 2               Micro-ondas                  62
# 161  Loja 4                  Cama box                  62
# 52   Loja 2                   Bateria                  61
# 24   Loja 1             Guarda roupas                  60
# ----------
#        Loja            Produto  quantidade_vendida
# 82   Loja 2  Jogo de tabuleiro                  32
# 11   Loja 1       Celular ABXY                  33
# 26   Loja 1            Headset                  33
# 178  Loja 4           Guitarra                  33
# 87   Loja 2     Mesa de jantar                  34

# %%
vendas_por_loja_produto = df.groupby(['Loja', 'Produto']).size().reset_index(name='quantidade_vendida')

for loja_nome in df['Loja'].unique():
    print(f'\n--- Loja: {loja_nome} ---')

    # Produtos mais vendidos
    mais_vendidos = vendas_por_loja_produto[vendas_por_loja_produto['Loja'] == loja_nome].sort_values('quantidade_vendida', ascending=False).head(5)

    # Produtos menos vendidos
    menos_vendidos = vendas_por_loja_produto[vendas_por_loja_produto['Loja'] == loja_nome].sort_values('quantidade_vendida', ascending=True).head(5)

    # Combinando os 5 mais vendidos e 5 menos vendidos em uma única tabela, sem a coluna 'Loja' e sem o índice
    print('5 produtos mais vendidos e 5 produtos menos vendidos:')
    display(pd.concat([mais_vendidos.drop(columns=['Loja']), menos_vendidos.drop(columns=['Loja'])]).style.hide(axis='index'))
# Out:
# --- Loja: Loja 1 ---
# 5 produtos mais vendidos e 5 produtos menos vendidos:
# <style type="text/css">
# </style>
# <table id="T_097a0" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_097a0_level0_col0" class="col_heading level0 col0" >Produto</th>
#       <th id="T_097a0_level0_col1" class="col_heading level0 col1" >quantidade_vendida</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_097a0_row0_col0" class="data row0 col0" >TV Led UHD 4K</td>
#       <td id="T_097a0_row0_col1" class="data row0 col1" >60</td>
#     </tr>
#     <tr>
#       <td id="T_097a0_row1_col0" class="data row1 col0" >Micro-ondas</td>
#       <td id="T_097a0_row1_col1" class="data row1 col1" >60</td>
#     </tr>
#     <tr>
#       <td id="T_097a0_row2_col0" class="data row2 col0" >Guarda roupas</td>
#       <td id="T_097a0_row2_col1" class="data row2 col1" >60</td>
#     </tr>
#     <tr>
#       <td id="T_097a0_row3_col0" class="data row3 col0" >Secadora de roupas</td>
#       <td id="T_097a0_row3_col1" class="data row3 col1" >58</td>
#     </tr>
#     <tr>
#       <td id="T_097a0_row4_col0" class="data row4 col0" >Blocos de montar</td>
#       <td id="T_097a0_row4_col1" class="data row4 col1" >56</td>
#     </tr>
#     <tr>
#       <td id="T_097a0_row5_col0" class="data row5 col0" >Celular ABXY</td>
#       <td id="T_097a0_row5_col1" class="data row5 col1" >33</td>
#     </tr>
#     <tr>
#       <td id="T_097a0_row6_col0" class="data row6 col0" >Headset</td>
#       <td id="T_097a0_row6_col1" class="data row6 col1" >33</td>
#     </tr>
#     <tr>
#       <td id="T_097a0_row7_col0" class="data row7 col0" >Panela de pressão</td>
#       <td id="T_097a0_row7_col1" class="data row7 col1" >35</td>
#     </tr>
#     <tr>
#       <td id="T_097a0_row8_col0" class="data row8 col0" >Pandeiro</td>
#       <td id="T_097a0_row8_col1" class="data row8 col1" >36</td>
#     </tr>
#     <tr>
#       <td id="T_097a0_row9_col0" class="data row9 col0" >Ciência de dados com python</td>
#       <td id="T_097a0_row9_col1" class="data row9 col1" >39</td>
#     </tr>
#   </tbody>
# </table>
# --- Loja: Loja 2 ---
# 5 produtos mais vendidos e 5 produtos menos vendidos:
# <style type="text/css">
# </style>
# <table id="T_5f544" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_5f544_level0_col0" class="col_heading level0 col0" >Produto</th>
#       <th id="T_5f544_level0_col1" class="col_heading level0 col1" >quantidade_vendida</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5f544_row0_col0" class="data row0 col0" >Iniciando em programação</td>
#       <td id="T_5f544_row0_col1" class="data row0 col1" >65</td>
#     </tr>
#     <tr>
#       <td id="T_5f544_row1_col0" class="data row1 col0" >Micro-ondas</td>
#       <td id="T_5f544_row1_col1" class="data row1 col1" >62</td>
#     </tr>
#     <tr>
#       <td id="T_5f544_row2_col0" class="data row2 col0" >Bateria</td>
#       <td id="T_5f544_row2_col1" class="data row2 col1" >61</td>
#     </tr>
#     <tr>
#       <td id="T_5f544_row3_col0" class="data row3 col0" >Violão</td>
#       <td id="T_5f544_row3_col1" class="data row3 col1" >58</td>
#     </tr>
#     <tr>
#       <td id="T_5f544_row4_col0" class="data row4 col0" >Pandeiro</td>
#       <td id="T_5f544_row4_col1" class="data row4 col1" >58</td>
#     </tr>
#     <tr>
#       <td id="T_5f544_row5_col0" class="data row5 col0" >Jogo de tabuleiro</td>
#       <td id="T_5f544_row5_col1" class="data row5 col1" >32</td>
#     </tr>
#     <tr>
#       <td id="T_5f544_row6_col0" class="data row6 col0" >Impressora</td>
#       <td id="T_5f544_row6_col1" class="data row6 col1" >34</td>
#     </tr>
#     <tr>
#       <td id="T_5f544_row7_col0" class="data row7 col0" >Mesa de jantar</td>
#       <td id="T_5f544_row7_col1" class="data row7 col1" >34</td>
#     </tr>
#     <tr>
#       <td id="T_5f544_row8_col0" class="data row8 col0" >Poltrona</td>
#       <td id="T_5f544_row8_col1" class="data row8 col1" >35</td>
#     </tr>
#     <tr>
#       <td id="T_5f544_row9_col0" class="data row9 col0" >Fone de ouvido</td>
#       <td id="T_5f544_row9_col1" class="data row9 col1" >37</td>
#     </tr>
#   </tbody>
# </table>
# --- Loja: Loja 3 ---
# 5 produtos mais vendidos e 5 produtos menos vendidos:
# <style type="text/css">
# </style>
# <table id="T_f474b" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_f474b_level0_col0" class="col_heading level0 col0" >Produto</th>
#       <th id="T_f474b_level0_col1" class="col_heading level0 col1" >quantidade_vendida</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f474b_row0_col0" class="data row0 col0" >Kit banquetas</td>
#       <td id="T_f474b_row0_col1" class="data row0 col1" >57</td>
#     </tr>
#     <tr>
#       <td id="T_f474b_row1_col0" class="data row1 col0" >Mesa de jantar</td>
#       <td id="T_f474b_row1_col1" class="data row1 col1" >56</td>
#     </tr>
#     <tr>
#       <td id="T_f474b_row2_col0" class="data row2 col0" >Cama king</td>
#       <td id="T_f474b_row2_col1" class="data row2 col1" >56</td>
#     </tr>
#     <tr>
#       <td id="T_f474b_row3_col0" class="data row3 col0" >Cômoda</td>
#       <td id="T_f474b_row3_col1" class="data row3 col1" >55</td>
#     </tr>
#     <tr>
#       <td id="T_f474b_row4_col0" class="data row4 col0" >Jogo de panelas</td>
#       <td id="T_f474b_row4_col1" class="data row4 col1" >55</td>
#     </tr>
#     <tr>
#       <td id="T_f474b_row5_col0" class="data row5 col0" >Blocos de montar</td>
#       <td id="T_f474b_row5_col1" class="data row5 col1" >35</td>
#     </tr>
#     <tr>
#       <td id="T_f474b_row6_col0" class="data row6 col0" >Jogo de copos</td>
#       <td id="T_f474b_row6_col1" class="data row6 col1" >36</td>
#     </tr>
#     <tr>
#       <td id="T_f474b_row7_col0" class="data row7 col0" >Micro-ondas</td>
#       <td id="T_f474b_row7_col1" class="data row7 col1" >36</td>
#     </tr>
#     <tr>
#       <td id="T_f474b_row8_col0" class="data row8 col0" >Mochila</td>
#       <td id="T_f474b_row8_col1" class="data row8 col1" >36</td>
#     </tr>
#     <tr>
#       <td id="T_f474b_row9_col0" class="data row9 col0" >Guitarra</td>
#       <td id="T_f474b_row9_col1" class="data row9 col1" >38</td>
#     </tr>
#   </tbody>
# </table>
# --- Loja: Loja 4 ---
# 5 produtos mais vendidos e 5 produtos menos vendidos:
# <style type="text/css">
# </style>
# <table id="T_2a2c8" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_2a2c8_level0_col0" class="col_heading level0 col0" >Produto</th>
#       <th id="T_2a2c8_level0_col1" class="col_heading level0 col1" >quantidade_vendida</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2a2c8_row0_col0" class="data row0 col0" >Cama box</td>
#       <td id="T_2a2c8_row0_col1" class="data row0 col1" >62</td>
#     </tr>
#     <tr>
#       <td id="T_2a2c8_row1_col0" class="data row1 col0" >Faqueiro</td>
#       <td id="T_2a2c8_row1_col1" class="data row1 col1" >59</td>
#     </tr>
#     <tr>
#       <td id="T_2a2c8_row2_col0" class="data row2 col0" >Cama king</td>
#       <td id="T_2a2c8_row2_col1" class="data row2 col1" >56</td>
#     </tr>
#     <tr>
#       <td id="T_2a2c8_row3_col0" class="data row3 col0" >Dashboards com Power BI</td>
#       <td id="T_2a2c8_row3_col1" class="data row3 col1" >56</td>
#     </tr>
#     <tr>
#       <td id="T_2a2c8_row4_col0" class="data row4 col0" >Cômoda</td>
#       <td id="T_2a2c8_row4_col1" class="data row4 col1" >55</td>
#     </tr>
#     <tr>
#       <td id="T_2a2c8_row5_col0" class="data row5 col0" >Guitarra</td>
#       <td id="T_2a2c8_row5_col1" class="data row5 col1" >33</td>
#     </tr>
#     <tr>
#       <td id="T_2a2c8_row6_col0" class="data row6 col0" >Guarda roupas</td>
#       <td id="T_2a2c8_row6_col1" class="data row6 col1" >34</td>
#     </tr>
#     <tr>
#       <td id="T_2a2c8_row7_col0" class="data row7 col0" >Violão</td>
#       <td id="T_2a2c8_row7_col1" class="data row7 col1" >37</td>
#     </tr>
#     <tr>
#       <td id="T_2a2c8_row8_col0" class="data row8 col0" >Ciência de dados com python</td>
#       <td id="T_2a2c8_row8_col1" class="data row8 col1" >38</td>
#     </tr>
#     <tr>
#       <td id="T_2a2c8_row9_col0" class="data row9 col0" >Lavadora de roupas</td>
#       <td id="T_2a2c8_row9_col1" class="data row9 col1" >38</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Calculando a quantidade de vendas para cada produto por loja
vendas_por_loja_produto = df.groupby(['Loja', 'Produto', 'Categoria do Produto']).size().reset_index(name='quantidade_vendida')

# Preparando uma lista para armazenar os dados do resumo
dados_resumo = []

for nome_loja in df['Loja'].unique():
    # Filtrando os dados para a loja atual
    vendas_loja = vendas_por_loja_produto[vendas_por_loja_produto['Loja'] == nome_loja]

    # Obtendo o produto mais vendido para a loja atual
    mais_vendido = vendas_loja.sort_values(by='quantidade_vendida', ascending=False).iloc[0]

    # Obtendo o produto menos vendido para a loja atual
    menos_vendido = vendas_loja.sort_values(by='quantidade_vendida', ascending=True).iloc[0]

    # Adicionando dados à lista de resumo
    dados_resumo.append({
        'loja': nome_loja,
        'produto_mais_vendido': mais_vendido['Produto'],
        'quantidade_mais_vendido': mais_vendido['quantidade_vendida'],
        'categoria_mais_vendido': mais_vendido['Categoria do Produto'],
        'produto_menos_vendido': menos_vendido['Produto'],
        'quantidade_menos_vendido': menos_vendido['quantidade_vendida'],
        'categoria_menos_vendido': menos_vendido['Categoria do Produto']
    })

# Criando um DataFrame a partir dos dados do resumo
summary_df = pd.DataFrame(dados_resumo)

# Exibindo a tabela de resumo final
display(summary_df)
# Out:
#      loja      produto_mais_vendido  quantidade_mais_vendido  \
# 0  Loja 1             TV Led UHD 4K                       60
# 1  Loja 2  Iniciando em programação                       65
# 2  Loja 3             Kit banquetas                       57
# 3  Loja 4                  Cama box                       62
#
#   categoria_mais_vendido produto_menos_vendido  quantidade_menos_vendido  \
# 0            eletronicos          Celular ABXY                        33
# 1                 livros     Jogo de tabuleiro                        32
# 2                 moveis      Blocos de montar                        35
# 3                 moveis              Guitarra                        33
#
#   categoria_menos_vendido
# 0             eletronicos
# 1              brinquedos
# 2              brinquedos
# 3   instrumentos musicais

# %%
total_vendas_por_produto = df.groupby('Produto').size().reset_index(name='quantidade_vendida')

print('5 Produtos Mais Vendidos (Todas as Lojas):')
produtos_mais_vendidos_geral = total_vendas_por_produto.sort_values('quantidade_vendida', ascending=False).head(5)
display(produtos_mais_vendidos_geral)

print('\n5 Produtos Menos Vendidos (Todas as Lojas):')
produtos_menos_vendidos_geral = total_vendas_por_produto.sort_values('quantidade_vendida', ascending=True).head(5)
display(produtos_menos_vendidos_geral)
# Out:
# 5 Produtos Mais Vendidos (Todas as Lojas):
#                      Produto  quantidade_vendida
# 17                    Cômoda                 210
# 10  Carrinho controle remoto                 206
# 37               Micro-ondas                 206
# 1                    Bateria                 203
# 9                  Cama king                 201
# 5 Produtos Menos Vendidos (Todas as Lojas):
#                         Produto  quantidade_vendida
# 11                 Celular ABXY                 157
# 26                      Headset                 158
# 38                      Mochila                 163
# 25                     Guitarra                 165
# 13  Ciência de dados com python                 166

# %% [markdown]
# # 5. Frete Médio por Loja
